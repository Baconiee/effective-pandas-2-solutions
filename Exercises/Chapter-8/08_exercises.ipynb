# %%
import pandas as pd

# %% [markdown]
# 1.

# %%
s1 = pd.Series([1, 2, 3], dtype='int64[pyarrow]')

# %%
# Add a numeric series to itself.
s1 + s1
# Out:
# 0    2
# 1    4
# 2    6
# dtype: int64[pyarrow]

# %%
# Add 10 to a numeric series.
s1 + 10
# Out:
# 0    11
# 1    12
# 2    13
# dtype: int64[pyarrow]

# %%
s2 = pd.Series([4, 5, 6], dtype='int64[pyarrow]')

# %%
# Use the .add method to add a numeric series.
s1.add(s2)
# Out:
# 0    5
# 1    7
# 2    9
# dtype: int64[pyarrow]

# %%
# Read the documentation for the .add method.
help(s1.add)
# Out:
# Help on method add in module pandas.core.series:
#
# add(other, level=None, fill_value=None, axis: 'Axis' = 0) -> 'Series' method of pandas.Series instance
#     Return Addition of series and other, element-wise (binary operator `add`).
#
#     Equivalent to ``series + other``, but with support to substitute a fill_value
#     for missing data in either one of the inputs.
#
#     Parameters
#     ----------
#     other : Series or scalar value
#         With which to compute the addition.
#     level : int or name
#         Broadcast across a level, matching Index values on the
#         passed MultiIndex level.
#     fill_value : None or float value, default None (NaN)
#         Fill existing missing (NaN) values, and any new element needed for
#         successful Series alignment, with this value before computation.
#         If data in both corresponding Series locations is missing
#         the result of filling (at that location) will be missing.
#     axis : {0 or 'index'}
# ...
