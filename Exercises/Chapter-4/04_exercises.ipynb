# %% [markdown]
# 1.
#     ![image.png](attachment:image.png)
# ```text
#     We can think of a spreadsheet with data like an excel table.
#     Spreadsheets are heterogeneous. Which means "A" column can save the data as an integer
#     meanwhile Column "B" can save it as a string. DataFrames are perfect for this.
#     It is tabular so we should use pd.DataFrame as a data structure.

# %% [markdown]
# 2.
# ```text
#     If we have a SQL Database with data then our tables are gonna be also in a tabular form.
#     You may ask what if the table we are gonna work on has only one column? In that case should we use a Series?
#     The answer is no. Even then we still should be using DataFrames.
#     We only "downgrade" it to a Series when we need to do specific math or when a function explicitly
#     df["SalePrice"].mean() --> We get SalePrice column values and calculate the mean. We only use the SalePrice column which is a Series.
#     asks for a 1D input. We are still gonna be using the DataFrames as containers to wrap the items which are Series.
