# %% [markdown]
# 1.
# ```text
#     JupyterLab is the newer version of the Jupyter Notebook. It is more extensible and has more features than the Jupyter Notebook.
#     You can customize it for you specific needs.

# %% [markdown]
# 2.
# ```text
#     You can press "a" on keyboard to create a code cell above the cell you currently on.
#     You can also press "b" on keyboard to create a code cell below the cell you currently on.
# ```

# %% [markdown]
# 3.
# ```text
#     You can change a cell's type from code to markdown by pressing "m" on your keyboard.

# %% [markdown]
# 4.
# ````text
#     You can use this shortcut for Windows/Linux --> Ctrl + S
#     And this for Mac --> Cmd + S

# %% [markdown]
# 5.
# ```text
#     Interrupting a kernel forces the current cell to stop immediately but preserves all your variables and data in memory.

# %% [markdown]
# 6.
# ```text
#     You can restart the kernel by pressing 0 twice on your keyboard.
#     Restarting, however, is used to clear a 'stuck' state by wiping the memory clean and starting with a fresh environment.
#     Which mean you need to import ur libraries and run your code again.
