# %% [markdown]
# 1.
# ```text
#     To represent the number of people in the United States, we have two possible data type which are numerical.
#     float and int. The number of people in United States can't be fractional so we use int.
#     United States population is around 350 million so using dtype='int32[pyarrow]' is enough(the range of int32 is -2,147,483,648 to 2,147,483,647).
#     There are approximately 8.3 billian people in the world. As we can see, using int32 would cause to overflow.
#     Hence we should use dtype='int64[pyarrow]'(the range of int64 is -9,223,372,036,854,775,808 to 9,223,372,036,854,775,807)

# %% [markdown]
# 2.
# ```text
#     To describe a product, we have two options. Categorical or string.
#     We can freely explain a product with string but a category is a low cardinality type of data thats why it is inappropriate. --> dtype='pd.ArrowDType(pa.String())'
#     Again we can use a string to represent the name of a product. --> dtype='pd.ArrowDType(pa.String())'
#     And for the price of a product, we should use float data type because the price of a product can be fractional. --> dtype='float64[pyarrow]'
#     Note: The bits should be according to you specific needs. Float32 is the most safe choice but again think before using it.

# %% [markdown]
# 3.
# ```text
#     You should use dtype='timestamp[ns][pyarrow]' to represent the date and time of a stock trade because it need high precision.
#     But you should be using dtype='timestamp[s][pyarrow]' for date of birth because you don't need that my precision and the range of years it can cover is a lot more
#     then the [ns] version.
